# %% [markdown]
# # **Title of Project** : **Hand Written Digit Prediction**

# %% [markdown]
# -------------

# %% [markdown]
# ## **Objective**: Classify the data and analyse the digit dataset

# %% [markdown]
# ## **Data Source**:kaggle.com

# %% [markdown]
# ## **Import Library**

# %%
import numpy as np  import pandas as pd

# %% [markdown]
# ## **Import Data**

# %%
from sklearn.datasets import load_digits

# %% [markdown]
# ## **Describe Data**

# %%
df = load_digits()

# %% [markdown]
# ## **Data Visualization**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Data Preprocessing**

# %%
df.images.shape

# %% [markdown]
# ## **Define Target Variable (y) and Feature Variables (X)**

# %%
X_train,X_test,y_train,y_test

# %% [markdown]
# ## **Train Test Split**

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %% [markdown]
# ## **Modeling**

# %%
from sklearn.ensemble import RandomForestClassifier rf=RandomForestClassifier()  rf.fit(X_train,y_train)

# %% [markdown]
# ## **Model Evaluation**

# %%
confusion_matrix(y_test,y_pred)

# %% [markdown]
# ## **Prediction**

# %%
y_pred=rf.predict(X_test)

# %% [markdown]
# ## **Explaination**
